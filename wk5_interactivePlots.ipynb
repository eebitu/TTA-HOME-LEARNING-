# %%
import altair as alt
import pandas as pd
# Import seaborn
import seaborn as sns

# %%
# Check out available datasets
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
# Load my data
data = sns.load_dataset('tips')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
brush = alt.selection_interval()

# %%
points = alt.Chart(data).mark_point().encode(
    x='total_bill:Q',
    y='tip:Q',
    opacity=alt.value(0.2),
    color=alt.value('red')

)
points
# Out:
# alt.Chart(...)

# %%
bars = alt.Chart(data).mark_bar().encode(
    y='size:N',
    color='size:N',
    x='count(size):Q'
)

bars
# Out:
# alt.Chart(...)

# %%
## The largest size in this dataset is the size 2 of  the customers.

# %%
#interarctive chart of the data
int_tips = alt.Chart(data).mark_circle(filled=True).encode(
         alt.X('total_bill'),
         alt.Y('tip'),
         alt.Size('size'),
         alt.Color('sex'),
         alt.OpacityValue(0.7),
         tooltip = [alt.Tooltip('day'),
         alt.Tooltip('total_bill'),
         alt.Tooltip('tip'),
         alt.Tooltip('smoker'),
         alt.Tooltip('time'),
         alt.Tooltip('size'),
         alt.Tooltip('sex')]   
        ).interactive()

int_tips
# Out:
# alt.Chart(...)

# %%
## The interactive chart above displays all the features in the tip dataset. The x axis displays the total bill and the y axis displays the tip from the customers. 
## The highest tip and bill comes from a male customer with the highest bill of £50 who gives a tip of of £10. This male customer ate dinner on Saturday, smokes and is in the size 3 category.  
## The lowest tip and bill mix if from a female customer with a total bill £3.07 and gives a tip of £1. This customer ate dinner on a saturday, is a smoker and in the size 1 category.

# %%
points & bars
# Out:
# alt.VConcatChart(...)

# %%
int_tips & bars
# Out:
# alt.VConcatChart(...)
